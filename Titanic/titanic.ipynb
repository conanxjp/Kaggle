# %%
import os
import numpy as np
import pandas as pd

# %%
ROOT = os.getcwd()
DATA_FOLDER = '/data'
TRAIN_FILE = '/train.csv'
TEST_FILE = '/test.csv'
TRAIN_PATH = os.getcwd() + DATA_FOLDER + TRAIN_FILE
TEST_PATH = os.getcwd() + DATA_FOLDER + TEST_FILE

# %%
train = pd.read_csv(TRAIN_PATH)
test = pd.read_csv(TEST_PATH)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
maleAgeAvg = np.nanmean(train['Age'])
femaleAgeAvg = np.nanmean(train['Age'])

# %%
# use male and female age averages to fill the nan cells
# ## method 1: use np.isnan to find nan cells
# train.loc[(train['Sex'] == 'male') & np.isnan(train['Age']), 'Age'] = maleAgeAvg
# train.loc[(train['Sex'] == 'female') & np.isnan(train['Age']), 'Age'] = femaleAgeAvg
## method 2: use df.fillna() to fill in nan cells
train.loc[train['Sex'] == 'male', 'Age'] = train['Age'][train['Sex'] == 'male'].fillna(maleAgeAvg)
train.loc[train['Sex'] == 'female', 'Age'] = train['Age'][train['Sex'] == 'female'].fillna(femaleAgeAvgeAvg)

# %%
train.loc[trai]
# Out:
# False

# %%
train.loc[train['Sex'] == 'male']
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 0              1         0       3                  Braund, Mr. Owen Harris
# 4              5         0       3                 Allen, Mr. William Henry
# 5              6         0       3                         Moran, Mr. James
# 6              7         0       1                  McCarthy, Mr. Timothy J
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 12            13         0       3           Saundercock, Mr. William Henry
# 13            14         0       3              Andersson, Mr. Anders Johan
# 16            17         0       3                     Rice, Master. Eugene
# 17            18         1       2             Williams, Mr. Charles Eugene
# 20            21         0       2                     Fynney, Mr. Joseph J
# 21            22         1       2                    Beesley, Mr. Lawrence
# 23            24         1       1             Sloper, Mr. William Thompson
# 26            27         0       3                  Emir, Mr. Farred Chehab
# 27            28         0       1           Fortune, Mr. Charles Alexander
# 29            30         0       3                      Todoroff, Mr. Lalio
# 30            31         0       1                 Uruchurtu, Don. Manuel E
# 33            34         0       2                    Wheadon, Mr. Edward H
# 34            35         0       1                  Meyer, Mr. Edgar Joseph
# 35            36         0       1           Holverson, Mr. Alexander Oskar
# 36            37         1       3                         Mamee, Mr. Hanna
# 37            38         0       3                 Cann, Mr. Ernest Charles
# 42            43         0       3                      Kraeff, Mr. Theodor
# 45            46         0       3                 Rogers, Mr. William John
# 46            47         0       3                        Lennon, Mr. Denis
# 48            49         0       3                      Samaan, Mr. Youssef
# 50            51         0       3               Panula, Master. Juha Niilo
# 51            52         0       3             Nosworthy, Mr. Richard Cater
# 54            55         0       1           Ostby, Mr. Engelhart Cornelius
# 55            56         1       1                        Woolner, Mr. Hugh
# 57            58         0       3                      Novel, Mr. Mansouer
# ..           ...       ...     ...                                      ...
# 840          841         0       3              Alhomaki, Mr. Ilmari Rudolf
# 841          842         0       2                 Mudd, Mr. Thomas Charles
# 843          844         0       3               Lemberopolous, Mr. Peter L
# 844          845         0       3                      Culumovic, Mr. Jeso
# 845          846         0       3                      Abbing, Mr. Anthony
# 846          847         0       3                 Sage, Mr. Douglas Bullen
# 847          848         0       3                       Markoff, Mr. Marin
# 848          849         0       2                        Harper, Rev. John
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 851          852         0       3                      Svensson, Mr. Johan
# 857          858         1       1                   Daly, Mr. Peter Denis
# 859          860         0       3                         Razi, Mr. Raihed
# 860          861         0       3                  Hansen, Mr. Claus Peter
# 861          862         0       2              Giles, Mr. Frederick Edward
# 864          865         0       2                   Gill, Mr. John William
# 867          868         0       1     Roebling, Mr. Washington Augustus II
# 868          869         0       3              van Melkebeke, Mr. Philemon
# 869          870         1       3          Johnson, Master. Harold Theodor
# 870          871         0       3                        Balkic, Mr. Cerin
# 872          873         0       1                 Carlsson, Mr. Frans Olof
# 873          874         0       3              Vander Cruyssen, Mr. Victor
# 876          877         0       3            Gustafsson, Mr. Alfred Ossian
# 877          878         0       3                     Petroff, Mr. Nedelio
# 878          879         0       3                       Laleff, Mr. Kristo
# 881          882         0       3                       Markun, Mr. Johann
# 883          884         0       2            Banfield, Mr. Frederick James
# 884          885         0       3                   Sutehall, Mr. Henry Jr
# 886          887         0       2                    Montvila, Rev. Juozas
# 889          890         1       1                    Behr, Mr. Karl Howell
# 890          891         0       3                      Dooley, Mr. Patrick
#
#       Sex        Age  SibSp  Parch            Ticket      Fare        Cabin  \
# 0    male  22.000000      1      0         A/5 21171    7.2500          NaN
# 4    male  35.000000      0      0            373450    8.0500          NaN
# 5    male  29.699118      0      0            330877    8.4583          NaN
# 6    male  54.000000      0      0             17463   51.8625          E46
# 7    male   2.000000      3      1            349909   21.0750          NaN
# 12   male  20.000000      0      0         A/5. 2151    8.0500          NaN
# 13   male  39.000000      1      5            347082   31.2750          NaN
# 16   male   2.000000      4      1            382652   29.1250          NaN
# 17   male  29.699118      0      0            244373   13.0000          NaN
# 20   male  35.000000      0      0            239865   26.0000          NaN
# 21   male  34.000000      0      0            248698   13.0000          D56
# 23   male  28.000000      0      0            113788   35.5000           A6
# 26   male  29.699118      0      0              2631    7.2250          NaN
# 27   male  19.000000      3      2             19950  263.0000  C23 C25 C27
# 29   male  29.699118      0      0            349216    7.8958          NaN
# 30   male  40.000000      0      0          PC 17601   27.7208          NaN
# 33   male  66.000000      0      0        C.A. 24579   10.5000          NaN
# 34   male  28.000000      1      0          PC 17604   82.1708          NaN
# 35   male  42.000000      1      0            113789   52.0000          NaN
# 36   male  29.699118      0      0              2677    7.2292          NaN
# 37   male  21.000000      0      0        A./5. 2152    8.0500          NaN
# 42   male  29.699118      0      0            349253    7.8958          NaN
# 45   male  29.699118      0      0   S.C./A.4. 23567    8.0500          NaN
# 46   male  29.699118      1      0            370371   15.5000          NaN
# 48   male  29.699118      2      0              2662   21.6792          NaN
# 50   male   7.000000      4      1           3101295   39.6875          NaN
# 51   male  21.000000      0      0        A/4. 39886    7.8000          NaN
# 54   male  65.000000      0      1            113509   61.9792          B30
# 55   male  29.699118      0      0             19947   35.5000          C52
# 57   male  28.500000      0      0              2697    7.2292          NaN
# ..    ...        ...    ...    ...               ...       ...          ...
# 840  male  20.000000      0      0  SOTON/O2 3101287    7.9250          NaN
# 841  male  16.000000      0      0       S.O./P.P. 3   10.5000          NaN
# 843  male  34.500000      0      0              2683    6.4375          NaN
# 844  male  17.000000      0      0            315090    8.6625          NaN
# 845  male  42.000000      0      0         C.A. 5547    7.5500          NaN
# 846  male  29.699118      8      2          CA. 2343   69.5500          NaN
# 847  male  35.000000      0      0            349213    7.8958          NaN
# 848  male  28.000000      0      1            248727   33.0000          NaN
# 850  male   4.000000      4      2            347082   31.2750          NaN
# 851  male  74.000000      0      0            347060    7.7750          NaN
# 857  male  51.000000      0      0            113055   26.5500          E17
# 859  male  29.699118      0      0              2629    7.2292          NaN
# 860  male  41.000000      2      0            350026   14.1083          NaN
# 861  male  21.000000      1      0             28134   11.5000          NaN
# 864  male  24.000000      0      0            233866   13.0000          NaN
# 867  male  31.000000      0      0          PC 17590   50.4958          A24
# 868  male  29.699118      0      0            345777    9.5000          NaN
# 869  male   4.000000      1      1            347742   11.1333          NaN
# 870  male  26.000000      0      0            349248    7.8958          NaN
# 872  male  33.000000      0      0               695    5.0000  B51 B53 B55
# 873  male  47.000000      0      0            345765    9.0000          NaN
# 876  male  20.000000      0      0              7534    9.8458          NaN
# 877  male  19.000000      0      0            349212    7.8958          NaN
# 878  male  29.699118      0      0            349217    7.8958          NaN
# 881  male  33.000000      0      0            349257    7.8958          NaN
# 883  male  28.000000      0      0  C.A./SOTON 34068   10.5000          NaN
# 884  male  25.000000      0      0   SOTON/OQ 392076    7.0500          NaN
# 886  male  27.000000      0      0            211536   13.0000          NaN
# 889  male  26.000000      0      0            111369   30.0000         C148
# 890  male  32.000000      0      0            370376    7.7500          NaN
#
#     Embarked
# 0          S
# 4          S
# 5          Q
# 6          S
# 7          S
# 12         S
# 13         S
# 16         Q
# 17         S
# 20         S
# 21         S
# 23         S
# 26         C
# 27         S
# 29         S
# 30         C
# 33         S
# 34         C
# 35         S
# 36         C
# 37         S
# 42         C
# 45         S
# 46         Q
# 48         C
# 50         S
# 51         S
# 54         C
# 55         S
# 57         C
# ..       ...
# 840        S
# 841        S
# 843        C
# 844        S
# 845        S
# 846        S
# 847        C
# 848        S
# 850        S
# 851        S
# 857        S
# 859        C
# 860        S
# 861        S
# 864        S
# 867        S
# 868        S
# 869        S
# 870        S
# 872        S
# 873        S
# 876        S
# 877        S
# 878        S
# 881        S
# 883        S
# 884        S
# 886        S
# 889        C
# 890        Q
#
# [577 rows x 12 columns]
